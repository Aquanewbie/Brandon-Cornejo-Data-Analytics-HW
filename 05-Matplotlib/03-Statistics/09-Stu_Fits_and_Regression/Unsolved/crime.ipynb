# %%
# Dependencies
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd

# %%
# Load crime data set into pandas
crime_data = pd.read_csv("../Resources/crime_data.csv")
crime_data
# Out:
#       year   population  violent crime  violent crime rate  \
# 0   1994.0  260327021.0      1857670.0               713.6
# 1   1995.0  262803276.0      1798792.0               684.5
# 2   1996.0  265228572.0      1688540.0               636.6
# 3   1997.0  267783607.0      1636096.0               611.0
# 4   1998.0  270248003.0      1533887.0               567.6
# 5   1999.0  272690813.0      1426044.0               523.0
# 6   2000.0  281421906.0      1425486.0               506.5
# 7   2001.0  285317559.0      1439480.0               504.5
# 8   2002.0  287973924.0      1423677.0               494.4
# 9   2003.0  290788976.0      1383676.0               475.8
# 10  2004.0  293656842.0      1360088.0               463.2
# 11  2005.0  296507061.0      1390745.0               469.0
# 12  2006.0  299398484.0      1435123.0               479.3
# 13  2007.0  301621157.0      1422970.0               471.8
# 14  2008.0  304059724.0      1394461.0               458.6
# 15  2009.0  307006550.0      1325896.0               431.9
# 16  2010.0  309330219.0      1251248.0               404.5
# 17  2011.0  311587816.0      1206005.0               387.1
# 18  2012.0  313873685.0      1217057.0               387.8
# 19  2013.0  316128839.0      1163146.0               367.9
#
#     murder and non-negligent manslaughter  \
# 0                                 23326.0
# 1                                 21606.0
# 2                                 19645.0
# 3                                 18208.0
# 4                                 16974.0
# 5                                 15522.0
# 6                                 15586.0
# 7                                 16037.0
# 8                                 16229.0
# 9                                 16528.0
# 10                                16148.0
# 11                                16740.0
# 12                                17309.0
# 13                                17128.0
# 14                                16465.0
# 15                                15399.0
# 16                                14722.0
# 17                                14661.0
# 18                                14856.0
# 19                                14196.0
#
#      murder and non-negligent manslaughter rate      rape  rape rate  \
# 0                                           9.0  102216.0       39.3
# 1                                           8.2   97470.0       37.1
# 2                                           7.4   96252.0       36.3
# 3                                           6.8   96153.0       35.9
# 4                                           6.3   93144.0       34.5
# 5                                           5.7   89411.0       32.8
# 6                                           5.5   90178.0       32.0
# 7                                           5.6   90863.0       31.8
# 8                                           5.6   95235.0       33.1
# 9                                           5.7   93883.0       32.3
# 10                                          5.5   95089.0       32.4
# 11                                          5.6   94347.0       31.8
# 12                                          5.8   94472.0       31.6
# 13                                          5.7   92160.0       30.6
# 14                                          5.4   90750.0       29.8
# 15                                          5.0   89241.0       29.1
# 16                                          4.8   85593.0       27.7
# 17                                          4.7   84175.0       27.0
# 18                                          4.7   85141.0       27.1
# 19                                          4.5   79770.0       25.2
#
#      robbery  robbery rate   aggravated assault  aggravated assault rate  \
# 0   618949.0         237.8            1113179.0                    427.6
# 1   580509.0         220.9            1099207.0                    418.3
# 2   535594.0         201.9            1037049.0                    391.0
# 3   498534.0         186.2            1023201.0                    382.1
# 4   447186.0         165.5             976583.0                    361.4
# 5   409371.0         150.1             911740.0                    334.3
# 6   408016.0         145.0             911706.0                    324.0
# 7   423557.0         148.5             909023.0                    318.6
# 8   420806.0         146.1             891407.0                    309.5
# 9   414235.0         142.5             859030.0                    295.4
# 10  401470.0         136.7             847381.0                    288.6
# 11  417438.0         140.8             862220.0                    290.8
# 12  449246.0         150.0             874096.0                    292.0
# 13  447324.0         148.3             866358.0                    287.2
# 14  443563.0         145.9             843683.0                    277.5
# 15  408742.0         133.1             812514.0                    264.7
# 16  369089.0         119.3             781844.0                    252.8
# 17  354746.0         113.9             752423.0                    241.5
# 18  355051.0         113.1             762009.0                    242.8
# 19  345031.0         109.1             724149.0                    229.1
#
#     property crime  property crime rate   burglary  burglary rate  \
# 0       12131873.0               4660.2  2712774.0         1042.1
# 1       12063935.0               4590.5  2593784.0          987.0
# 2       11805323.0               4451.0  2506400.0          945.0
# 3       11558475.0               4316.3  2460526.0          918.8
# 4       10951827.0               4052.5  2332735.0          863.2
# 5       10208334.0               3743.6  2100739.0          770.4
# 6       10182584.0               3618.3  2050992.0          728.8
# 7       10437189.0               3658.1  2116531.0          741.8
# 8       10455277.0               3630.6  2151252.0          747.0
# 9       10442862.0               3591.2  2154834.0          741.0
# 10      10319386.0               3514.1  2144446.0          730.3
# 11      10174754.0               3431.5  2155448.0          726.9
# 12      10019601.0               3346.6  2194993.0          733.1
# 13       9882212.0               3276.4  2190198.0          726.1
# 14       9774152.0               3214.6  2228887.0          733.0
# 15       9337060.0               3041.3  2203313.0          717.7
# 16       9112625.0               2945.9  2168459.0          701.0
# 17       9052743.0               2905.4  2185140.0          701.3
# 18       9001992.0               2868.0  2109932.0          672.2
# 19       8632512.0               2730.7  1928465.0          610.0
#
#     larceny-theft  larceny-theft rate  motor vehicle theft  \
# 0       7879812.0              3026.9            1539287.0
# 1       7997710.0              3043.2            1472441.0
# 2       7904685.0              2980.3            1394238.0
# 3       7743760.0              2891.8            1354189.0
# 4       7376311.0              2729.5            1242781.0
# 5       6955520.0              2550.7            1152075.0
# 6       6971590.0              2477.3            1160002.0
# 7       7092267.0              2485.7            1228391.0
# 8       7057379.0              2450.7            1246646.0
# 9       7026802.0              2416.5            1261226.0
# 10      6937089.0              2362.3            1237851.0
# 11      6783447.0              2287.8            1235859.0
# 12      6626363.0              2213.2            1198245.0
# 13      6591542.0              2185.4            1100472.0
# 14      6586206.0              2166.1             959059.0
# 15      6338095.0              2064.5             795652.0
# 16      6204601.0              2005.8             739565.0
# 17      6151095.0              1974.1             716508.0
# 18      6168874.0              1965.4             723186.0
# 19      6004453.0              1899.4             699594.0
#
#     motor vehicle theft rate
# 0                      591.3
# 1                      560.3
# 2                      525.7
# 3                      505.7
# 4                      459.9
# 5                      422.5
# 6                      412.2
# 7                      430.5
# 8                      432.9
# 9                      433.7
# 10                     421.5
# 11                     416.8
# 12                     400.2
# 13                     364.9
# 14                     315.4
# 15                     259.2
# 16                     239.1
# 17                     230.0
# 18                     230.4
# 19                     221.3

# %%
# Generate a scatter plot of year versus violent crime rate
x_values = crime_data.iloc[:,0]
y_values = crime_data.iloc[:,3]
plt.scatter(x_values,y_values)
plt.xlabel('Year')
plt.ylabel('Violent Crime Rate')
plt.show()

# %%
# Perform a linear regression on year versus violent crime rate
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Year')
plt.ylabel('Violent Crime Rate')
plt.show()

# %%
# Create equation of line to calculate predicted violent crime rate

# %%
# Plot the linear model on top of scatter plot

# %%
# Repeat plotting scatter and linear model for year versus murder rate

# %%
# Repeat plotting scatter and linear model for year versus aggravated assault

# %%
# Generate a facet plot of all 3 figures

# %%
# Calculate the crime rates for 2019
