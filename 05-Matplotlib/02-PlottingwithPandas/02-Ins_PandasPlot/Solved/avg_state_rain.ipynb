# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x1188c5160>,
#   <matplotlib.axis.XTick at 0x1188aca90>,
#   <matplotlib.axis.XTick at 0x1188ac780>,
#   <matplotlib.axis.XTick at 0x118c1dc88>,
#   <matplotlib.axis.XTick at 0x118c1dd30>,
#   <matplotlib.axis.XTick at 0x118c2e5c0>,
#   <matplotlib.axis.XTick at 0x118c2eb38>,
#   <matplotlib.axis.XTick at 0x118c37160>,
#   <matplotlib.axis.XTick at 0x118c37668>,
#   <matplotlib.axis.XTick at 0x118c37be0>,
#   <matplotlib.axis.XTick at 0x118c3e198>,
#   <matplotlib.axis.XTick at 0x118c3e710>,
#   <matplotlib.axis.XTick at 0x118c3ec88>,
#   <matplotlib.axis.XTick at 0x118c3e588>,
#   <matplotlib.axis.XTick at 0x118c375c0>,
#   <matplotlib.axis.XTick at 0x118c44160>,
#   <matplotlib.axis.XTick at 0x118c447b8>,
#   <matplotlib.axis.XTick at 0x118c44d30>,
#   <matplotlib.axis.XTick at 0x118c4c2e8>,
#   <matplotlib.axis.XTick at 0x118c4c860>,
#   <matplotlib.axis.XTick at 0x118c4cdd8>,
#   <matplotlib.axis.XTick at 0x118c52390>,
#   <matplotlib.axis.XTick at 0x118c4c6d8>,
#   <matplotlib.axis.XTick at 0x118c44898>,
#   <matplotlib.axis.XTick at 0x118c52ba8>,
#   <matplotlib.axis.XTick at 0x118c52ef0>,
#   <matplotlib.axis.XTick at 0x118c594a8>,
#   <matplotlib.axis.XTick at 0x118c59a20>,
#   <matplotlib.axis.XTick at 0x118c59e80>,
#   <matplotlib.axis.XTick at 0x118c60550>,
#   <matplotlib.axis.XTick at 0x118c60ac8>,
#   <matplotlib.axis.XTick at 0x118c670f0>,
#   <matplotlib.axis.XTick at 0x118c608d0>,
#   <matplotlib.axis.XTick at 0x118c52e48>,
#   <matplotlib.axis.XTick at 0x118c67518>,
#   <matplotlib.axis.XTick at 0x118c67a90>,
#   <matplotlib.axis.XTick at 0x118c6f0b8>,
#   <matplotlib.axis.XTick at 0x118c6f5c0>,
#   <matplotlib.axis.XTick at 0x118c6fb38>,
#   <matplotlib.axis.XTick at 0x118c77160>,
#   <matplotlib.axis.XTick at 0x118c77668>,
#   <matplotlib.axis.XTick at 0x118c6f3c8>,
#   <matplotlib.axis.XTick at 0x118c675f8>,
#   <matplotlib.axis.XTick at 0x118c77d68>,
#   <matplotlib.axis.XTick at 0x118c7d160>,
#   <matplotlib.axis.XTick at 0x118c7d6a0>,
#   <matplotlib.axis.XTick at 0x118c7dc18>,
#   <matplotlib.axis.XTick at 0x118c851d0>,
#   <matplotlib.axis.XTick at 0x118c85748>,
#   <matplotlib.axis.XTick at 0x118c85cc0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(433.94444444444446, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
# Filter the DataFrame down only to those columns to chart
state_and_inches = rain_df[["State","Inches"]]

# Set the index to be "State" so they will be used as labels
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
state_and_inches.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
# Pandas can also plot multiple columns if the DataFrame includes them
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))

# PandasPlot.set_xticklabels() can be used to set the tick labels as well
multi_plot.set_xticklabels(rain_df["State"], rotation=45)

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
