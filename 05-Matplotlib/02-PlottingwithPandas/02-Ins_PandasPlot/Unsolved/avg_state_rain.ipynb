# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Using MatplotLib to Chart a DataFrame

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x11c0c27f0>,
#   <matplotlib.axis.XTick at 0x11c0c2128>,
#   <matplotlib.axis.XTick at 0x11c0aae10>,
#   <matplotlib.axis.XTick at 0x11c3d4470>,
#   <matplotlib.axis.XTick at 0x11c3d4940>,
#   <matplotlib.axis.XTick at 0x11c3d47b8>,
#   <matplotlib.axis.XTick at 0x11c3e31d0>,
#   <matplotlib.axis.XTick at 0x11c3e3748>,
#   <matplotlib.axis.XTick at 0x11c3e3cc0>,
#   <matplotlib.axis.XTick at 0x11c3ea278>,
#   <matplotlib.axis.XTick at 0x11c3ea7f0>,
#   <matplotlib.axis.XTick at 0x11c3ead68>,
#   <matplotlib.axis.XTick at 0x11c3f0320>,
#   <matplotlib.axis.XTick at 0x11c3f0898>,
#   <matplotlib.axis.XTick at 0x11c3ea1d0>,
#   <matplotlib.axis.XTick at 0x11c3e35c0>,
#   <matplotlib.axis.XTick at 0x11c3f06a0>,
#   <matplotlib.axis.XTick at 0x11c3f7358>,
#   <matplotlib.axis.XTick at 0x11c3f78d0>,
#   <matplotlib.axis.XTick at 0x11c3f7e48>,
#   <matplotlib.axis.XTick at 0x11c3fe400>,
#   <matplotlib.axis.XTick at 0x11c3fe978>,
#   <matplotlib.axis.XTick at 0x11c3feef0>,
#   <matplotlib.axis.XTick at 0x11c3fe7f0>,
#   <matplotlib.axis.XTick at 0x11c3f7828>,
#   <matplotlib.axis.XTick at 0x11c405390>,
#   <matplotlib.axis.XTick at 0x11c405a90>,
#   <matplotlib.axis.XTick at 0x11c40b080>,
#   <matplotlib.axis.XTick at 0x11c40b5c0>,
#   <matplotlib.axis.XTick at 0x11c40bb38>,
#   <matplotlib.axis.XTick at 0x11c413128>,
#   <matplotlib.axis.XTick at 0x11c413668>,
#   <matplotlib.axis.XTick at 0x11c413be0>,
#   <matplotlib.axis.XTick at 0x11c413710>,
#   <matplotlib.axis.XTick at 0x11c405fd0>,
#   <matplotlib.axis.XTick at 0x11c41d0f0>,
#   <matplotlib.axis.XTick at 0x11c41d630>,
#   <matplotlib.axis.XTick at 0x11c41dba8>,
#   <matplotlib.axis.XTick at 0x11c422160>,
#   <matplotlib.axis.XTick at 0x11c4226d8>,
#   <matplotlib.axis.XTick at 0x11c422c50>,
#   <matplotlib.axis.XTick at 0x11c42a208>,
#   <matplotlib.axis.XTick at 0x11c422550>,
#   <matplotlib.axis.XTick at 0x11c41d588>,
#   <matplotlib.axis.XTick at 0x11c42a630>,
#   <matplotlib.axis.XTick at 0x11c42ac88>,
#   <matplotlib.axis.XTick at 0x11c431240>,
#   <matplotlib.axis.XTick at 0x11c4317b8>,
#   <matplotlib.axis.XTick at 0x11c431d30>,
#   <matplotlib.axis.XTick at 0x11c4382e8>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# ### Using Pandas to Chart a DataFrame

# %%
state_and_inches=rain_df[["State", "Inches"]]
#Set index to "State"-used as labels"
state_and_inches = state_and_inches.set_index("State")
state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
state_and_inches.plot(kind="bar", figsize=(20,3))
plt.title("Average Rain Per State")
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
multi_plot = rain_df.plot(kind="bar", figsize=(20,5))
multi_plot.set_xticklabels(rain_df["State"], rotation=45)
plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
