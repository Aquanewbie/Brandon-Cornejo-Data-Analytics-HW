# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = [ "Bromeliads", "Conifers", "Tigers", "Shits"]
sizes = [1,2,3,4]
colors = ["red", "orange", "lightcoral", "lightskyblue"]
explode = (0.5, 0,0.5,1)

# %%
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%.2f%%',shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x11f9cb320>,
#   <matplotlib.patches.Wedge at 0x11f9cb400>,
#   <matplotlib.patches.Wedge at 0x1203a9908>,
#   <matplotlib.patches.Wedge at 0x11fe20ac8>],
#  [Text(-1.483494170112716, 0.5993705425207219, 'Bromeliads'),
#   Text(-0.932852894856852, -0.5829112081245234, 'Conifers'),
#   Text(0.8478709117011181, -1.356876898281902, 'Tigers'),
#   Text(0.7866736091842468, 1.9470861903400762, 'Shits')],
#  [Text(-1.0199022419524921, 0.4120672479829963, '10.00%'),
#   Text(-0.508828851740101, -0.3179515680679218, '20.00%'),
#   Text(0.5829112517945185, -0.9328528675688076, '30.00%'),
#   Text(0.5993703689022832, 1.4834942402591054, '40.00%')])
