# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x115f8c630>,
#   <matplotlib.axis.XTick at 0x115f62f60>,
#   <matplotlib.axis.XTick at 0x115f62cf8>,
#   <matplotlib.axis.XTick at 0x1162f4198>,
#   <matplotlib.axis.XTick at 0x1162f4630>,
#   <matplotlib.axis.XTick at 0x1162f4ba8>,
#   <matplotlib.axis.XTick at 0x1162ff198>,
#   <matplotlib.axis.XTick at 0x1162ff6d8>,
#   <matplotlib.axis.XTick at 0x1162ffc50>,
#   <matplotlib.axis.XTick at 0x116307208>,
#   <matplotlib.axis.XTick at 0x116307780>,
#   <matplotlib.axis.XTick at 0x116307cf8>,
#   <matplotlib.axis.XTick at 0x1162ffd30>,
#   <matplotlib.axis.XTick at 0x1162f46d8>,
#   <matplotlib.axis.XTick at 0x116310320>,
#   <matplotlib.axis.XTick at 0x116310898>,
#   <matplotlib.axis.XTick at 0x116310e10>,
#   <matplotlib.axis.XTick at 0x1163153c8>,
#   <matplotlib.axis.XTick at 0x116315940>,
#   <matplotlib.axis.XTick at 0x116315eb8>,
#   <matplotlib.axis.XTick at 0x11631c470>,
#   <matplotlib.axis.XTick at 0x116315a20>,
#   <matplotlib.axis.XTick at 0x116310198>,
#   <matplotlib.axis.XTick at 0x11631c908>,
#   <matplotlib.axis.XTick at 0x11631ce80>,
#   <matplotlib.axis.XTick at 0x116323438>,
#   <matplotlib.axis.XTick at 0x1163239b0>,
#   <matplotlib.axis.XTick at 0x116323f28>,
#   <matplotlib.axis.XTick at 0x11632a4e0>,
#   <matplotlib.axis.XTick at 0x11632aa58>,
#   <matplotlib.axis.XTick at 0x11632aba8>,
#   <matplotlib.axis.XTick at 0x116323908>,
#   <matplotlib.axis.XTick at 0x116310128>,
#   <matplotlib.axis.XTick at 0x11632f518>,
#   <matplotlib.axis.XTick at 0x11632fa90>,
#   <matplotlib.axis.XTick at 0x1163360b8>,
#   <matplotlib.axis.XTick at 0x1163365c0>,
#   <matplotlib.axis.XTick at 0x116336b38>,
#   <matplotlib.axis.XTick at 0x116340160>,
#   <matplotlib.axis.XTick at 0x116340668>,
#   <matplotlib.axis.XTick at 0x1163369b0>,
#   <matplotlib.axis.XTick at 0x116310278>,
#   <matplotlib.axis.XTick at 0x116340b00>,
#   <matplotlib.axis.XTick at 0x116346128>,
#   <matplotlib.axis.XTick at 0x116346630>,
#   <matplotlib.axis.XTick at 0x116346ba8>,
#   <matplotlib.axis.XTick at 0x11634e198>,
#   <matplotlib.axis.XTick at 0x11634e6d8>,
#   <matplotlib.axis.XTick at 0x11634ec50>,
#   <matplotlib.axis.XTick at 0x11634e6a0>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(0, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
